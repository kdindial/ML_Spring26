# %% [markdown]
# # PS1 Data
# Authors
# - David W Hogg (NYU)
# - Clark Miyamoto (NYU)
#
# Requirements:
# - `astropy`

# %% [markdown]
# # Get the Labels

# %%
import numpy as np
from astropy.io import fits # You might need to pip install this
import pylab as plt # only needed for verification

# %%
hdul = fits.open("labels.fits")
# Out:
# Filename: labels.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       5   ()
#   1                1 BinTableHDU    399   733901R x 191C   [30A, 6A, 20A, 30A, D, D, D, D, E, E, E, E, E, E, E, 32A, E, E, J, J, J, J, J, J, 132A, 32A, 32A, J, E, E, K, 132A, K, 132A, E, E, E, E, E, E, E, E, E, E, E, J, J, E, E, E, E, E, E, K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 8A, E, 9K, K, 256A, E, E, E, 27E, 27E, 27E, 27E, 27E, 27E, J, K, 10A, 27E, 27E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J, E, E, E, J]
#   2                1 ImageHDU         6   (360,)   int64
#   3                1 BinTableHDU     26   1R x 6C   [7514E, 576A, 540A, 27J, 1296A, 420A]
#   4                1 BinTableHDU     14   2215R x 3C   [12A, 32A, 12A]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 hdul = fits.open("labels.fits")
#       3 hdul.info()
# ----> 4 data = hdul.data
#       6 print(data.columns)
#
# AttributeError: 'HDUList' object has no attribute 'data'

# %%
path_labels = "./labels.fits"
allstar = fits.open(path_labels)

# %%
# the labels are in an enormous table in element [1] of this FITS file
labels = allstar[1].data
plt.scatter(labels['TEFF'], labels['LOGG'], s=1)
plt.xlim(6000, 3500)
plt.ylim(5, 0)
# Out:
# (5.0, 0.0)

# %%
# make a reasonable red-giant-branch sample
RGB = True
RGB = np.logical_and(RGB, labels['TEFF'] > 3500.)
RGB = np.logical_and(RGB, labels['TEFF'] < 5400.)
RGB = np.logical_and(RGB, labels['LOGG'] < 3.0)
RGB = np.logical_and(RGB, labels['LOGG'] > 0.0)
RGB = np.logical_and(RGB, labels['H'] < 10.5)
print(np.sum(RGB))
# Out:
# 145991

# %%
# make a plot that an astronomer likes to see
RGB_labels = labels[RGB]
plt.scatter(RGB_labels['TEFF'], RGB_labels['LOGG'], c=RGB_labels['FE_H'], s=1)
plt.xlim(5400, 3500)
plt.xlabel("effective temperature")
plt.ylim(3., 0.)
plt.ylabel("log10 surface gravity")
plt.colorbar(label="metallicity")

# %%
# make train, validation, and test data sets
rng = np.random.default_rng(17)
N_RGB = len(RGB_labels)
N_train, N_valid, N_test = 1024, 256, 512
I = rng.permutation(N_RGB)
I_train = I[0:N_train]
I_valid = I[N_train:N_train+N_valid]
I_test = I[N_train+N_valid:N_train+N_valid+N_test]

train_labels = RGB_labels[I_train]
valid_labels = RGB_labels[I_valid]
test_labels = RGB_labels[I_test]
print(len(train_labels), len(valid_labels), len(test_labels))
# Out:
# 1024 256 512

# %%
train_labels[0]
# Out:
# ('2M05282261-6908287', 'lco25m', '30Dor', 'none', np.float64(82.094231), np.float64(-69.141312), np.float64(279.65967016748186), np.float64(-32.57819471348452), np.float32(9.275), np.float32(0.091), np.float32(8.15), np.float32(0.036), np.float32(7.796), np.float32(0.026), np.float32(nan), 'none', np.float32(0.7518415), np.float32(0.5291884), np.int32(0), np.int32(0), np.int32(0), np.int32(-2146959360), np.int32(0), np.int32(0), 'APOGEE2_COMMIS_SOUTH_SPEC', 'apogee2s', 'halo', np.int32(1), np.float32(251.74564), np.float32(264.86063), np.int64(0), '', np.int64(0), '', np.float32(267.62988), np.float32(0.0), np.float32(0.038580444), np.float32(3770.2532), np.float32(0.6031771), np.float32(-0.46269518), np.float32(0.0), np.float32(0.0), np.float32(28.305626), np.float32(22.40921), np.float32(12.347154), np.int32(0), np.int32(1), np.float32(250.0), np.float32(0.0), np.float32(-9999.99), np.float32(9999.99), np.float32(-9999.99), np.float32(9999.99), np.int64(4658058264937692032), np.float32(0.16730255), np.float32(0.0447248), np.float32(1.8229289), np.float32(0.0581675), np.float32(0.65111303), np.float32(0.0617094), np.float32(12.177), np.float32(12.6036), np.float32(10.8983), np.float32(nan), np.float32(nan), np.float32(6070.9243), np.float32(4774.727), np.float32(9026.661), np.float32(6387.9087), np.float32(4932.166), np.float32(7994.616), 'Mg_a', np.float32(55.6801), array([       0, 33554432,      257,        0,        0,        0,
#               0,        0,        0], dtype='>i8'), np.int64(262148), 'VMICRO_WARN,VMICRO_BAD', np.float32(0.026483897), np.float32(0.025951557), np.float32(0.008783604), array([-0.581692  , -0.578086  , -0.458     , -0.63469696, -0.523048  ,
#        -0.664817  , -1.300119  , -0.69603336,         nan, -0.541934  ,
#        -0.61193097, -0.70024997, -0.8658068 , -0.683396  , -0.849798  ,
#        -0.580546  , -0.536768  , -0.62205   , -0.57289   , -0.6195175 ,
#                nan,         nan,         nan, -0.57234   ,         nan,
#                nan,         nan], dtype='>f4'), array([0.0118222 , 0.02374546, 0.01364667, 0.01037504, 0.05414693,
#        0.01390547, 0.02215345, 0.01496153, 0.11382093, 0.05252995,
#        0.04175423, 0.01665907, 0.01712097, 0.05189184, 0.04537591,
#        0.03444825, 0.01791477, 0.01040265, 0.02933563, 0.01432443,
#        0.00560426, 1.        , 1.        , 0.02698223, 0.08057632,
#        1.        , 0.03693786], dtype='>f4'), array([ 0.032108  ,  0.035714  ,  0.1558    , -0.020897  ,  0.09075201,
#        -0.051017  , -0.68631905, -0.0822334 ,         nan,  0.071866  ,
#         0.00186902, -0.08645   , -0.25200683, -0.069596  , -0.23599803,
#         0.03325397,  0.07703197, -0.00825   ,  0.04091001, -0.00571752,
#                nan,         nan,         nan,  0.04145998,         nan,
#                nan,         nan], dtype='>f4'), array([0.00811553, 0.02213469, 0.01059853, 0.00580852, 0.05482511,
#        0.01092975, 0.02376295, 0.01224519, 0.11382093, 0.05182175,
#        0.04263001, 0.01426962, 0.01480625, 0.0511748 , 0.04618306,
#        0.03550471, 0.01987062, 0.0134951 , 0.0305693 , 0.01670604,
#        0.00560426, 1.        , 1.        , 0.0283186 , 0.08057632,
#        1.        , 0.03693786], dtype='>f4'), array([ 45.21682  ,  20.691883 ,  54.72679  ,  64.5357   ,   6.8183613,
#        184.11958  ,  47.011055 ,  72.243706 ,  24.92872  ,  21.237333 ,
#         78.59592  ,   4.150018 , 502.45828  ,  12.676518 ,  47.315125 ,
#         20.691883 ,  13.683588 ,  64.13573  ,  15.240527 ,  34.442924 ,
#        100.438446 ,         nan,         nan,  48.79777  , 308.46082  ,
#                nan,  14.696029 ], dtype='>f4'), array([0.9777757 , 0.9645341 , 0.9882672 , 0.98426414, 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 0.86689365, 0.98324734, 1.        , 0.98933613,
#        1.        , 1.        , 0.9843622 , 1.        , 0.96700335,
#        1.        , 1.        , 1.        , 0.9758674 , 1.        ,
#        1.        , 1.        ], dtype='>f4'), np.int32(1), np.int64(0), '', array([-0.581692  , -0.578086  , -0.458     , -0.69136   , -0.54245   ,
#        -0.72833997, -1.1588    , -0.690634  ,         nan, -0.56571597,
#        -0.68169   , -0.682245  , -0.86538   , -0.641645  , -0.89476   ,
#        -0.58296   , -0.65367   , -0.62205   , -0.62096   , -0.66291   ,
#                nan,         nan,         nan, -0.51668   ,         nan,
#                nan,         nan], dtype='>f4'), array([ 0.032108  ,  0.035714  ,  0.1558    , -0.07756   ,  0.07134998,
#        -0.11454   , -0.545     , -0.076834  ,         nan,  0.048084  ,
#        -0.06788999, -0.068445  , -0.25158   , -0.027845  , -0.28096002,
#         0.03083998, -0.03987002, -0.00825   , -0.00716001, -0.04911   ,
#                nan,         nan,         nan,  0.09711999,         nan,
#                nan,         nan], dtype='>f4'), np.float32(3802.778), np.float32(4.8084416), np.float32(0.5848838), np.float32(0.02673805), np.float32(-0.6138), np.float32(0.00859666), np.float32(-0.037652), np.float32(0.0066767223), np.float32(4.5614195), np.float32(4.2341533), np.float32(nan), np.float32(3666.9), np.float32(0.47391), np.float32(0.040358007), np.float32(0.040358007), np.float32(0.011822201), np.int32(0), np.float32(0.04396397), np.float32(0.04396397), np.float32(0.023745462), np.int32(0), np.float32(0.16404998), np.float32(0.16404998), np.float32(0.013646666), np.int32(0), np.float32(-0.012646973), np.float32(-0.06931001), np.float32(0.010375038), np.int32(0), np.float32(0.099002), np.float32(0.07959998), np.float32(0.05414693), np.int32(0), np.float32(-0.04276699), np.float32(-0.10628998), np.float32(0.0139054665), np.int32(0), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(-0.07398337), np.float32(-0.068584025), np.float32(0.014961529), np.int32(0), np.float32(nan), np.float32(nan), np.float32(0.11382093), np.int32(2), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(0.010119021), np.float32(-0.05963999), np.float32(0.041754227), np.int32(0), np.float32(-0.07819998), np.float32(-0.06019503), np.float32(0.016659066), np.int32(0), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(-0.22774804), np.float32(-0.27271003), np.float32(0.04537591), np.int32(0), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64), np.float32(-0.62205), np.float32(-0.62205), np.float32(0.010402653), np.int32(0), np.float32(0.049160004), np.float32(0.0010899901), np.float32(0.029335633), np.int32(0), np.float32(0.0025324821), np.float32(-0.040859997), np.float32(0.014324427), np.int32(0), np.float32(nan), np.float32(nan), np.float32(0.0056042564), np.int32(2), np.float32(nan), np.float32(nan), np.float32(nan), np.int32(64))

# %% [markdown]
# Here how you get `LOGG`

# %%
train_labels_logg = train_labels['LOGG']
print(train_labels_logg.shape) # (num_spectra, 1)
# Out:
# (1024,)

# %% [markdown]
# # Get the Features

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
train_features = np.load('./train_features.npy')
valid_features = np.load('./valid_features.npy')
test_features = np.load('./test_features.npy')
for i in range(10):
    plt.plot(train_features[i] + i)

# %%
print(train_features.shape) # (num_spectra, num_pixels)
# Out:
# (1024, 8575)

# %% [markdown]
# ____
#
# # If you want to download more data
#
# Run the `Get Labels` section, and then run this!
#
# Adjust `N_train`, `N_valid`, and `N_test`.

# %%
# make train, validation, and test data sets
rng = np.random.default_rng(17)
N_RGB = len(RGB_labels)
N_train, N_valid, N_test = 1024, 256, 512 # <- Adjust these for more data! 
I = rng.permutation(N_RGB)
I_train = I[0:N_train]
I_valid = I[N_train:N_train+N_valid]
I_test = I[N_train+N_valid:N_train+N_valid+N_test]
train_labels = RGB_labels[I_train]
valid_labels = RGB_labels[I_valid]
test_labels = RGB_labels[I_test]
print(len(train_labels), len(valid_labels), len(test_labels))

# %%
base_url = "https://data.sdss.org/sas/dr17/apogee/spectro/aspcap/dr17/synspec_rev1/"
def get_features(labels):
    features = None
    for l in labels:
        url = base_url + l['TELESCOPE'] + "/" + l['FIELD'] + "/aspcapStar-dr17-" + l['APOGEE_ID'] + ".fits"
        x = fits.open(url)[1].data
        if features is None:
            features = x[None, :]
        else:
            features = np.concatenate((features, x[None, :]), axis=0)
    return features

# %%
# Downloads data from SDSS
# This will take a while, the first time you run it. Don't be alarmed.
train_features_downloaded = get_features(train_labels)
valid_features_downloaded = get_features(valid_labels)
test_features_downloaded = get_features(test_labels)
print(train_features_downloaded.shape, valid_features_downloaded.shape, test_features_downloaded.shape)
